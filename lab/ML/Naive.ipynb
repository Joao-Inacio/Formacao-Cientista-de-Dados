# %% [markdown]
# ### Pratica de machine learning
# Algoritmo Naïve Bayes

# %%
# Importação das bibliotecas
import pandas as pd
import sklearn as skl
import seaborn as srn 
import statistics as sts

# %%
ds = pd.read_csv('melb_data.csv')
ds.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
ds['Landsize'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: Landsize
# Non-Null Count  Dtype
# --------------  -----
# 13580 non-null  float64
# dtypes: float64(1)
# memory usage: 106.2 KB

# %%
ds['BuildingArea'].isnull().sum()
# Out:
# 6450

# %%
mean = sts.median(ds['BuildingArea'])
mean
# Out:
# 134.5

# %%
mean2 = mean / 2
mean2
# Out:
# 67.25

# %%
ds['BuildingArea'].isnull().sum()
# Out:
# 1193

# %%
ds.loc[(ds['Landsize'] < 134.5), 'BuildingArea'] = mean

# %%
ds['BuildingArea'].isnull().sum()
# Out:
# 5257

# %%
ds.head()
# Out:
#        Suburb           Address  Rooms   Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St    2.0      h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St    2.0      h  1035000.0      S  Biggin
# 2       134.5             134.5  134.5  134.5      134.5  134.5   134.5
# 3  Abbotsford  40 Federation La    3.0      h   850000.0     PI  Biggin
# 4       134.5             134.5  134.5  134.5      134.5  134.5   134.5
#
#         Date  Distance  Postcode  ...  Bathroom    Car  Landsize  \
# 0  3/12/2016       2.5    3067.0  ...       1.0    1.0     202.0
# 1  4/02/2016       2.5    3067.0  ...       1.0    0.0     156.0
# 2      134.5     134.5     134.5  ...     134.5  134.5     134.5
# 3  4/03/2017       2.5    3067.0  ...       2.0    1.0      94.0
# 4      134.5     134.5     134.5  ...     134.5  134.5     134.5
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0        134.50        NaN        Yarra  -37.7996    144.9984
# ...

# %%
ds['BuildingArea'].describe()
# Out:
# count    13580.000000
# mean       121.936432
# std         26.212732
# min         67.250000
# 25%        134.500000
# 50%        134.500000
# 75%        134.500000
# max        134.500000
# Name: BuildingArea, dtype: float64

# %%
ds.head()
# Out:
#        Suburb           Address  Rooms   Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St    2.0      h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St    2.0      h  1035000.0      S  Biggin
# 2       134.5             134.5  134.5  134.5      134.5  134.5   134.5
# 3  Abbotsford  40 Federation La    3.0      h   850000.0     PI  Biggin
# 4       134.5             134.5  134.5  134.5      134.5  134.5   134.5
#
#         Date  Distance  Postcode  ...  Bathroom    Car  Landsize  \
# 0  3/12/2016       2.5    3067.0  ...       1.0    1.0     202.0
# 1  4/02/2016       2.5    3067.0  ...       1.0    0.0     156.0
# 2      134.5     134.5     134.5  ...     134.5  134.5     134.5
# 3  4/03/2017       2.5    3067.0  ...       2.0    1.0      94.0
# 4      134.5     134.5     134.5  ...     134.5  134.5     134.5
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0        134.50        NaN        Yarra  -37.7996    144.9984
# ...
