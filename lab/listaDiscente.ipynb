# %% [markdown]
# ### Praticando Analise exploratoria

# %%
import pandas as pd 
import seaborn as srn 
import statistics as sts

# %%
dados = pd.read_csv('lista_disc.csv')
dados.head()
# Out:
#                         id_discente    matricula  ano_ingresso  \
# 0  0003ba85ff2e992a07361dbe7e28d0bf   2018102***          2018
# 1  00082dd79190f2e00b15da27afcae03b   2019101***          2019
# 2  0016b115d8bcfce421766b146f40a388   2013102***          2013
# 3  0028bbd61a14e1a811dfc2617d5e2544   2017107***          2017
# 4  003b1ab7e5226903162e76581c17a333   2019104***          2019
#
#    periodo_ingresso  periodo_atual sexo  idade   raça    pais  \
# 0                 1            5.0    M     25  Negra  Angola
# 1                 1            3.0    F     22  Parda  Brasil
# 2                 1           15.0    M     40  Parda  Brasil
# 3                 1            7.0    F     21  Negra  Brasil
# 4                 1            3.0    F     20  Negra  Brasil
#
#                          curso nivel   modalidade estado      polo  \
# 0                   MATEMÁTICA     G   Presencial  Ceará       NaN
# 1                    PEDAGOGIA     G   Presencial  Ceará       NaN
# ...

# %%
dados.shape
# Out:
# (5962, 19)

# %%
agrupado = dados.groupby(['raça']).size()
agrupado
# Out:
# raça
# Amarela            60
# Branca            546
# Indígena          110
# Negra            2209
# Não declarada     299
# Parda            2731
# dtype: int64

# %%
agrupado.plot.bar(color='cyan')
# Out:
# <AxesSubplot:xlabel='raça'>

# %%
agrupado = dados.groupby(['ano_nascimento']).size()
agrupado
# Out:
# ano_nascimento
# 1954     1
# 1962     2
# 1963     1
# 1966     1
# 1969     1
# 1970     2
# 1971     2
# 1972     3
# 1973     4
# 1974     4
# 1975     5
# 1976     1
# 1977     3
# 1978     3
# 1979     5
# 1980     2
# 1981     4
# 1982     7
# 1983     4
# 1984     9
# 1985     9
# 1986    10
# 1987    14
# 1988    11
# 1989    10
# 1990    10
# 1991    14
# 1992     7
# 1993     9
# 1994    10
# 1995     3
# 1996     5
# 1997     7
# 1998     7
# 1999     4
# dtype: int64

# %%
agrupado.plot.bar(color='gray')
# Out:
# <AxesSubplot:xlabel='ano_nascimento'>

# %%
agrupado = dados.groupby(['pais']).size()
agrupado
# Out:
# pais
# Angola                  383
# Brasil                 4712
# Cabo Verde               54
# Guiné Bissau            689
# Itália                    1
# Moçambique               46
# São Tomé e Príncipe      69
# Timor Leste               8
# dtype: int64

# %%
agrupado.plot.bar(color='cyan')
# Out:
# <AxesSubplot:xlabel='pais'>

# %%
agrupado = dados.groupby(['sexo']).size()
agrupado
# Out:
# sexo
# F    98
# M    96
# dtype: int64

# %%
agrupado = dados.groupby(['curso']).size()
agrupado
# Out:
# curso
# ADMINISTRAÇÃO PÚBLICA                                                         255
# ADMINISTRAÇÃO PÚBLICA - SEMESTRAL                                             423
# AGRONOMIA                                                                     350
# ANTROPOLOGIA                                                                   75
# CIÊNCIAS BIOLÓGICAS                                                           208
# CIÊNCIAS DA NATUREZA E MATEMÁTICA                                               1
# CIÊNCIAS SOCIAIS                                                              123
# ENFERMAGEM                                                                    410
# ENGENHARIA DA COMPUTAÇÃO                                                       96
# ENGENHARIA DE ENERGIAS                                                        351
# ENSINO DE CIÊNCIAS  ANOS FINAIS DO ENSINO FUNDAMENTAL CIÊNCIA É DEZ",L"     103
# ...

# %%
agrupado.plot.bar(color='blue')
# Out:
# <AxesSubplot:xlabel='curso'>
# c:\Users\João Inácio\dadospython\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 150 (\x96) missing from current font.
#   func(*args, **kwargs)
# c:\Users\João Inácio\dadospython\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 147 (\x93) missing from current font.
#   func(*args, **kwargs)
# c:\Users\João Inácio\dadospython\venv\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\João Inácio\dadospython\venv\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
agrupado = dados.groupby(['estado']).size()
agrupado
# Out:
# estado
# Ceará    194
# dtype: int64

# %%
agrupado = dados.groupby(['idade']).size()
agrupado
# Out:
# idade
# 17      5
# 18    168
# 19    355
# 20    466
# 21    505
# 22    508
# 23    529
# 24    427
# 25    401
# 26    366
# 27    309
# 28    269
# 29    187
# 30    133
# 31    144
# 32    131
# 33    111
# 34     87
# 35     86
# 36     94
# 37     71
# 38     66
# 39     55
# 40     45
# 41     61
# 42     43
# 43     46
# 44     33
# 45     37
# 46     38
# 47     23
# 48     25
# 49     14
# 50     17
# 51     16
# 52     10
# 53     12
# 54     13
# 55     11
# 56     10
# 57      6
# 58      9
# 59      2
# 60      2
# 61      2
# 62      3
# 63      2
# 64      1
# 65      1
# 66      4
# 67      1
# 68      1
# 83      1
# dtype: int64

# %%
agrupado.plot.bar(color='green')
# Out:
# <AxesSubplot:xlabel='idade'>

# %%
agrupado = dados.groupby(['ano_ingresso']).size()
agrupado
# Out:
# ano_ingresso
# 2011      16
# 2012      34
# 2013      87
# 2014     151
# 2015     384
# 2016     524
# 2017    1076
# 2018    1293
# 2019    1327
# 2020    1070
# dtype: int64

# %%
agrupado.plot.bar(color='red')
# Out:
# <AxesSubplot:xlabel='ano_ingresso'>
