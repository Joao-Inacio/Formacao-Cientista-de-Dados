# %% [markdown]
# #### Formação Cientista de Dados
# * Gráfico de barras e setores

# %%
# Importação de libs
import pandas as pd

# %%
# Base de Dados
base = pd.read_csv('./data/insect.csv')
base.shape
# Out:
# (72, 2)

# %%
# Dados
base.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
# Agrupamento dos dados baseado do atributo 'spray', contando e somando os registros
agru = base.groupby(['spray'])['count'].sum()
agru
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
# Gráfico de Barra
agru.plot.bar(color='gray');

# %%
# Cores
agru.plot.bar(color=['blue','yellow','red','green','pink','orange',]);

# %%
# Gráfico de pizza
agru.plot.pie();

# %%
# Com Legenda
agru.plot.pie(legend=True);
