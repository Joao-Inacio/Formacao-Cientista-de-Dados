# %% [markdown]
# #### Formação Cientista de Dados
# * Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(
    previsores, classe, test_size = 0.3, random_state = 0
)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=1226768628),
#  DecisionTreeClassifier(max_features='auto', random_state=2015123558),
#  DecisionTreeClassifier(max_features='auto', random_state=294709488),
#  DecisionTreeClassifier(max_features='auto', random_state=1230197156),
#  DecisionTreeClassifier(max_features='auto', random_state=410838161),
#  DecisionTreeClassifier(max_features='auto', random_state=1802708822),
#  DecisionTreeClassifier(max_features='auto', random_state=602897572),
#  DecisionTreeClassifier(max_features='auto', random_state=33017209),
#  DecisionTreeClassifier(max_features='auto', random_state=252071427),
#  DecisionTreeClassifier(max_features='auto', random_state=1144689766),
#  DecisionTreeClassifier(max_features='auto', random_state=9001877),
#  DecisionTreeClassifier(max_features='auto', random_state=873418254),
#  DecisionTreeClassifier(max_features='auto', random_state=727119081),
#  DecisionTreeClassifier(max_features='auto', random_state=911513129),
#  DecisionTreeClassifier(max_features='auto', random_state=1676803894),
#  DecisionTreeClassifier(max_features='auto', random_state=126919483),
#  DecisionTreeClassifier(max_features='auto', random_state=906983190),
#  DecisionTreeClassifier(max_features='auto', random_state=940260690),
#  DecisionTreeClassifier(max_features='auto', random_state=329040301),
#  DecisionTreeClassifier(max_features='auto', random_state=1951010584),
#  DecisionTreeClassifier(max_features='auto', random_state=957634366),
#  DecisionTreeClassifier(max_features='auto', random_state=381107152),
#  DecisionTreeClassifier(max_features='auto', random_state=1188167149),
#  DecisionTreeClassifier(max_features='auto', random_state=1907667287),
#  DecisionTreeClassifier(max_features='auto', random_state=1601260553),
#  DecisionTreeClassifier(max_features='auto', random_state=259516629),
#  DecisionTreeClassifier(max_features='auto', random_state=508246945),
#  DecisionTreeClassifier(max_features='auto', random_state=83787209),
#  DecisionTreeClassifier(max_features='auto', random_state=370182523),
#  DecisionTreeClassifier(max_features='auto', random_state=703641994),
#  DecisionTreeClassifier(max_features='auto', random_state=1893344757),
#  DecisionTreeClassifier(max_features='auto', random_state=1048899658),
#  DecisionTreeClassifier(max_features='auto', random_state=1003783266),
#  DecisionTreeClassifier(max_features='auto', random_state=1269370568),
#  DecisionTreeClassifier(max_features='auto', random_state=1787649688),
#  DecisionTreeClassifier(max_features='auto', random_state=757462131),
#  DecisionTreeClassifier(max_features='auto', random_state=523812713),
#  DecisionTreeClassifier(max_features='auto', random_state=1859420829),
#  DecisionTreeClassifier(max_features='auto', random_state=317274833),
#  DecisionTreeClassifier(max_features='auto', random_state=1504611597),
#  DecisionTreeClassifier(max_features='auto', random_state=91252802),
#  DecisionTreeClassifier(max_features='auto', random_state=1540692813),
#  DecisionTreeClassifier(max_features='auto', random_state=641784033),
#  DecisionTreeClassifier(max_features='auto', random_state=1186278545),
#  DecisionTreeClassifier(max_features='auto', random_state=762250217),
#  DecisionTreeClassifier(max_features='auto', random_state=1110385364),
#  DecisionTreeClassifier(max_features='auto', random_state=627144594),
#  DecisionTreeClassifier(max_features='auto', random_state=313844561),
#  DecisionTreeClassifier(max_features='auto', random_state=1330409363),
#  DecisionTreeClassifier(max_features='auto', random_state=1206027355),
#  DecisionTreeClassifier(max_features='auto', random_state=1431739314),
#  DecisionTreeClassifier(max_features='auto', random_state=537833772),
#  DecisionTreeClassifier(max_features='auto', random_state=1804012663),
#  DecisionTreeClassifier(max_features='auto', random_state=1160246498),
#  DecisionTreeClassifier(max_features='auto', random_state=485164161),
#  DecisionTreeClassifier(max_features='auto', random_state=1521734672),
#  DecisionTreeClassifier(max_features='auto', random_state=1327140190),
#  DecisionTreeClassifier(max_features='auto', random_state=1816377740),
#  DecisionTreeClassifier(max_features='auto', random_state=2125611426),
#  DecisionTreeClassifier(max_features='auto', random_state=661176954),
#  DecisionTreeClassifier(max_features='auto', random_state=437524320),
#  DecisionTreeClassifier(max_features='auto', random_state=1871981773),
#  DecisionTreeClassifier(max_features='auto', random_state=1652557591),
#  DecisionTreeClassifier(max_features='auto', random_state=815442993),
#  DecisionTreeClassifier(max_features='auto', random_state=1804246128),
#  DecisionTreeClassifier(max_features='auto', random_state=1626083645),
#  DecisionTreeClassifier(max_features='auto', random_state=1435666086),
#  DecisionTreeClassifier(max_features='auto', random_state=1802019645),
#  DecisionTreeClassifier(max_features='auto', random_state=716465345),
#  DecisionTreeClassifier(max_features='auto', random_state=608680679),
#  DecisionTreeClassifier(max_features='auto', random_state=1413436914),
#  DecisionTreeClassifier(max_features='auto', random_state=1763504916),
#  DecisionTreeClassifier(max_features='auto', random_state=171456557),
#  DecisionTreeClassifier(max_features='auto', random_state=1171735492),
#  DecisionTreeClassifier(max_features='auto', random_state=1811194680),
#  DecisionTreeClassifier(max_features='auto', random_state=1270008117),
#  DecisionTreeClassifier(max_features='auto', random_state=40704862),
#  DecisionTreeClassifier(max_features='auto', random_state=194129472),
#  DecisionTreeClassifier(max_features='auto', random_state=1265950551),
#  DecisionTreeClassifier(max_features='auto', random_state=165660905),
#  DecisionTreeClassifier(max_features='auto', random_state=1831637545),
#  DecisionTreeClassifier(max_features='auto', random_state=136275682),
#  DecisionTreeClassifier(max_features='auto', random_state=1778144492),
#  DecisionTreeClassifier(max_features='auto', random_state=161116353),
#  DecisionTreeClassifier(max_features='auto', random_state=1429607546),
#  DecisionTreeClassifier(max_features='auto', random_state=2015481061),
#  DecisionTreeClassifier(max_features='auto', random_state=57180567),
#  DecisionTreeClassifier(max_features='auto', random_state=402100431),
#  DecisionTreeClassifier(max_features='auto', random_state=1326337240),
#  DecisionTreeClassifier(max_features='auto', random_state=676923916),
#  DecisionTreeClassifier(max_features='auto', random_state=454576338),
#  DecisionTreeClassifier(max_features='auto', random_state=1398564502),
#  DecisionTreeClassifier(max_features='auto', random_state=103772640),
#  DecisionTreeClassifier(max_features='auto', random_state=526672538),
#  DecisionTreeClassifier(max_features='auto', random_state=633064977),
#  DecisionTreeClassifier(max_features='auto', random_state=1651077072),
#  DecisionTreeClassifier(max_features='auto', random_state=212049749),
#  DecisionTreeClassifier(max_features='auto', random_state=2099957597),
#  DecisionTreeClassifier(max_features='auto', random_state=1211420276),
#  DecisionTreeClassifier(max_features='auto', random_state=2139708192)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7833333333333333
