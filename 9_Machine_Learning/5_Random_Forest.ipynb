# %% [markdown]
# #### Formação Cientista de Dados
# * Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos 
# previsores (variáveis independentes - X) 
# e da classe (variável dependente - y)
credito = pd.read_csv('./Data/Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
# Formato de matriz
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o 
# índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste 
# (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(
    previsores, classe, test_size = 0.3, random_state = 0
)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=1331530588),
#  DecisionTreeClassifier(max_features='auto', random_state=2146725972),
#  DecisionTreeClassifier(max_features='auto', random_state=1086294147),
#  DecisionTreeClassifier(max_features='auto', random_state=547798656),
#  DecisionTreeClassifier(max_features='auto', random_state=1459007677),
#  DecisionTreeClassifier(max_features='auto', random_state=917786163),
#  DecisionTreeClassifier(max_features='auto', random_state=1244240550),
#  DecisionTreeClassifier(max_features='auto', random_state=539795727),
#  DecisionTreeClassifier(max_features='auto', random_state=348183587),
#  DecisionTreeClassifier(max_features='auto', random_state=540001836),
#  DecisionTreeClassifier(max_features='auto', random_state=1187662529),
#  DecisionTreeClassifier(max_features='auto', random_state=1336991135),
#  DecisionTreeClassifier(max_features='auto', random_state=1619878582),
#  DecisionTreeClassifier(max_features='auto', random_state=1073049706),
#  DecisionTreeClassifier(max_features='auto', random_state=114944158),
#  DecisionTreeClassifier(max_features='auto', random_state=842174170),
#  DecisionTreeClassifier(max_features='auto', random_state=1711921262),
#  DecisionTreeClassifier(max_features='auto', random_state=750251346),
#  DecisionTreeClassifier(max_features='auto', random_state=252456647),
#  DecisionTreeClassifier(max_features='auto', random_state=1605344131),
#  DecisionTreeClassifier(max_features='auto', random_state=1681884423),
#  DecisionTreeClassifier(max_features='auto', random_state=18663464),
#  DecisionTreeClassifier(max_features='auto', random_state=165025346),
#  DecisionTreeClassifier(max_features='auto', random_state=841793052),
#  DecisionTreeClassifier(max_features='auto', random_state=363620607),
#  DecisionTreeClassifier(max_features='auto', random_state=1005100411),
#  DecisionTreeClassifier(max_features='auto', random_state=1817237449),
#  DecisionTreeClassifier(max_features='auto', random_state=765235444),
#  DecisionTreeClassifier(max_features='auto', random_state=26796710),
#  DecisionTreeClassifier(max_features='auto', random_state=1220271979),
#  DecisionTreeClassifier(max_features='auto', random_state=128175263),
#  DecisionTreeClassifier(max_features='auto', random_state=1210557405),
#  DecisionTreeClassifier(max_features='auto', random_state=69141321),
#  DecisionTreeClassifier(max_features='auto', random_state=1885548331),
#  DecisionTreeClassifier(max_features='auto', random_state=659654847),
#  DecisionTreeClassifier(max_features='auto', random_state=944926305),
#  DecisionTreeClassifier(max_features='auto', random_state=668591828),
#  DecisionTreeClassifier(max_features='auto', random_state=281407530),
#  DecisionTreeClassifier(max_features='auto', random_state=1628509221),
#  DecisionTreeClassifier(max_features='auto', random_state=156989710),
#  DecisionTreeClassifier(max_features='auto', random_state=289451031),
#  DecisionTreeClassifier(max_features='auto', random_state=2040049046),
#  DecisionTreeClassifier(max_features='auto', random_state=692705673),
#  DecisionTreeClassifier(max_features='auto', random_state=1769794763),
#  DecisionTreeClassifier(max_features='auto', random_state=1336112094),
#  DecisionTreeClassifier(max_features='auto', random_state=316955331),
#  DecisionTreeClassifier(max_features='auto', random_state=1166603244),
#  DecisionTreeClassifier(max_features='auto', random_state=1983546491),
#  DecisionTreeClassifier(max_features='auto', random_state=1443879172),
#  DecisionTreeClassifier(max_features='auto', random_state=2128515920),
#  DecisionTreeClassifier(max_features='auto', random_state=1406445126),
#  DecisionTreeClassifier(max_features='auto', random_state=419824269),
#  DecisionTreeClassifier(max_features='auto', random_state=1546966208),
#  DecisionTreeClassifier(max_features='auto', random_state=2097181862),
#  DecisionTreeClassifier(max_features='auto', random_state=2013927531),
#  DecisionTreeClassifier(max_features='auto', random_state=150321522),
#  DecisionTreeClassifier(max_features='auto', random_state=1672862018),
#  DecisionTreeClassifier(max_features='auto', random_state=86634443),
#  DecisionTreeClassifier(max_features='auto', random_state=1355902415),
#  DecisionTreeClassifier(max_features='auto', random_state=1162846706),
#  DecisionTreeClassifier(max_features='auto', random_state=1902630694),
#  DecisionTreeClassifier(max_features='auto', random_state=1754726169),
#  DecisionTreeClassifier(max_features='auto', random_state=1379018725),
#  DecisionTreeClassifier(max_features='auto', random_state=648107890),
#  DecisionTreeClassifier(max_features='auto', random_state=1721033015),
#  DecisionTreeClassifier(max_features='auto', random_state=510344266),
#  DecisionTreeClassifier(max_features='auto', random_state=448551668),
#  DecisionTreeClassifier(max_features='auto', random_state=653950181),
#  DecisionTreeClassifier(max_features='auto', random_state=294243597),
#  DecisionTreeClassifier(max_features='auto', random_state=712409059),
#  DecisionTreeClassifier(max_features='auto', random_state=853369020),
#  DecisionTreeClassifier(max_features='auto', random_state=1594455797),
#  DecisionTreeClassifier(max_features='auto', random_state=1225983378),
#  DecisionTreeClassifier(max_features='auto', random_state=222374798),
#  DecisionTreeClassifier(max_features='auto', random_state=1641792683),
#  DecisionTreeClassifier(max_features='auto', random_state=1679153705),
#  DecisionTreeClassifier(max_features='auto', random_state=1120979690),
#  DecisionTreeClassifier(max_features='auto', random_state=599336107),
#  DecisionTreeClassifier(max_features='auto', random_state=366531965),
#  DecisionTreeClassifier(max_features='auto', random_state=834171583),
#  DecisionTreeClassifier(max_features='auto', random_state=1745663912),
#  DecisionTreeClassifier(max_features='auto', random_state=2035342479),
#  DecisionTreeClassifier(max_features='auto', random_state=1796465399),
#  DecisionTreeClassifier(max_features='auto', random_state=1487951654),
#  DecisionTreeClassifier(max_features='auto', random_state=548100075),
#  DecisionTreeClassifier(max_features='auto', random_state=1477636845),
#  DecisionTreeClassifier(max_features='auto', random_state=797755152),
#  DecisionTreeClassifier(max_features='auto', random_state=979225289),
#  DecisionTreeClassifier(max_features='auto', random_state=1620227182),
#  DecisionTreeClassifier(max_features='auto', random_state=416200812),
#  DecisionTreeClassifier(max_features='auto', random_state=718575512),
#  DecisionTreeClassifier(max_features='auto', random_state=1110713510),
#  DecisionTreeClassifier(max_features='auto', random_state=1624109227),
#  DecisionTreeClassifier(max_features='auto', random_state=812486200),
#  DecisionTreeClassifier(max_features='auto', random_state=315249882),
#  DecisionTreeClassifier(max_features='auto', random_state=1762126270),
#  DecisionTreeClassifier(max_features='auto', random_state=1568736860),
#  DecisionTreeClassifier(max_features='auto', random_state=461854892),
#  DecisionTreeClassifier(max_features='auto', random_state=1855311569),
#  DecisionTreeClassifier(max_features='auto', random_state=931998594)]

# %%
# Fazendo a previsões
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7766666666666666
